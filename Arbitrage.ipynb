# %% [markdown]
# # Statistical Arbitrage for Sports Betting

# %% [markdown]
# Using: Live Sports Odds API
# Documentation Link: https://the-odds-api.com/

# %% [markdown]
# This program will look for statistical arbitrage opportunities in the upcoming eight games across all sports.

# %% [markdown]
# ### Importing Dependencies and Acquiring API Key

# %%
# !pip install XlsxWriter

# %%
import requests
import xlsxwriter
import pandas as pd
import numpy as np
import openpyxl
from openpyxl import Workbook, load_workbook
from openpyxl.styles import Border, Side, Font, Alignment, PatternFill, numbers

# %% [markdown]
# ### Defining Constants and Making API Call
# - ``BET_SIZE`` is the monetary amount in USD that you are willing to make for each bet. For example, if you define ``BET_SIZE`` as 100, you are telling the program that you want to bet a total of 100 dollars USD for each arbitrage opportunity that the program finds

# %%
SPORT = 'upcoming' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'h2h' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'decimal' # decimal | american

DATE_FORMAT = 'iso' # iso | unix

BET_SIZE = 100

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/sports/{SPORT}/odds',
    params={
        'api_key': "94933d26ba15c4b8c06a0eb9c12f57d0",
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
).json()

# %%
# odds_response
print(odds_response)
# Out:
# [{'id': '1527eddeab7d5bf553d0f95b53885a06', 'sport_key': 'soccer_efl_champ', 'sport_title': 'Championship', 'commence_time': '2023-04-07T11:32:16Z', 'home_team': 'Millwall', 'away_team': 'Luton Town', 'bookmakers': [{'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Luton Town', 'price': 5.75}, {'name': 'Millwall', 'price': 4.75}, {'name': 'Draw', 'price': 1.42}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.5}, {'name': 'Millwall', 'price': 5.3}, {'name': 'Draw', 'price': 1.37}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Luton Town', 'price': 5.75}, {'name': 'Millwall', 'price': 4.7}, {'name': 'Draw', 'price': 1.44}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Luton Town', 'price': 5.25}, {'name': 'Millwall', 'price': 4.4}, {'name': 'Draw', 'price': 1.47}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Luton Town', 'price': 5.3}, {'name': 'Millwall', 'price': 4.35}, {'name': 'Draw', 'price': 1.5}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Luton Town', 'price': 5.6}, {'name': 'Millwall', 'price': 4.8}, {'name': 'Draw', 'price': 1.42}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.0}, {'name': 'Millwall', 'price': 5.0}, {'name': 'Draw', 'price': 1.43}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-04-07T13:03:46Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:46Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.0}, {'name': 'Millwall', 'price': 5.0}, {'name': 'Draw', 'price': 1.4}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.25}, {'name': 'Millwall', 'price': 5.2}, {'name': 'Draw', 'price': 1.38}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.0}, {'name': 'Millwall', 'price': 5.0}, {'name': 'Draw', 'price': 1.38}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.25}, {'name': 'Millwall', 'price': 5.2}, {'name': 'Draw', 'price': 1.38}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-04-07T13:03:47Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:47Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.25}, {'name': 'Millwall', 'price': 5.2}, {'name': 'Draw', 'price': 1.38}]}]}]}, {'id': '9b42d1eed2654110b3a6d6abd47204cb', 'sport_key': 'soccer_efl_champ', 'sport_title': 'Championship', 'commence_time': '2023-04-07T12:04:22Z', 'home_team': 'Rotherham United', 'away_team': 'West Bromwich', 'bookmakers': [{'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Rotherham United', 'price': 4.25}, {'name': 'West Bromwich', 'price': 2.25}, {'name': 'Draw',  ...

# %% [markdown]
# ### Event Class
# - Each ``Event`` object represents an indivudal sporting event
# - The ``data`` parameter contains all of the odds data that is received from the API call

# %%
BOOKMAKER_INDEX = 0
NAME_INDEX = 1
ODDS_INDEX = 2
FIRST = 0

class Event:
    def __init__(self, data):
        self.data = data
        self.sport_key = data['sport_key']
        self.id = data['id']
        
    def find_best_odds(self):
        # number of possible outcomes for a sporting event
        num_outcomes = len(self.data['bookmakers'][FIRST]['markets'][FIRST]['outcomes'])
        self.num_outcomes = num_outcomes

        # finding the best odds for each outcome in each event
        best_odds = [[None, None, float('-inf')] for _ in range(num_outcomes)]
        # [Bookmaker, Name, Price]

        bookmakers = event.data['bookmakers']
        for index, bookmaker in enumerate(bookmakers):

            # determing the odds offered by each bookmaker
            for outcome in range(num_outcomes):

                # determining if any of the bookmaker odds are better than the current best odds
                bookmaker_odds = float(bookmaker['markets'][FIRST]['outcomes'][outcome]['price'])
                current_best_odds = best_odds[outcome][ODDS_INDEX]

                if bookmaker_odds > current_best_odds:
                    best_odds[outcome][BOOKMAKER_INDEX] = bookmaker['title']
                    best_odds[outcome][NAME_INDEX] = bookmaker['markets'][FIRST]['outcomes'][outcome]['name']
                    best_odds[outcome][ODDS_INDEX] = bookmaker_odds
                    
        self.best_odds = best_odds
        return best_odds
    
    def arbitrage(self):
        total_arbitrage_percentage = 0
        for odds in self.best_odds:
            total_arbitrage_percentage += (1.0 / odds[ODDS_INDEX])
            
        self.total_arbitrage_percentage = total_arbitrage_percentage
        self.expected_earnings = (BET_SIZE / total_arbitrage_percentage) - BET_SIZE
        
        # if the sum of the reciprocals of the odds is less than 1, there is opportunity for arbitrage
        if total_arbitrage_percentage < 1:
            return True
        return False
    
    # converts decimal/European best odds to American best odds
    def convert_decimal_to_american(self):
        best_odds = self.best_odds
        for odds in best_odds:
            decimal = odds[ODDS_INDEX]
            if decimal >= 2:
                american = (decimal - 1) * 100
            elif decimal < 2:
                american = -100 / (decimal - 1)
            odds[ODDS_INDEX] = round(american, 2)
        return best_odds
     
    def calculate_arbitrage_bets(self):
        bet_amounts = []
        for outcome in range(self.num_outcomes):
            individual_arbitrage_percentage = 1 / self.best_odds[outcome][ODDS_INDEX]
            bet_amount = (BET_SIZE * individual_arbitrage_percentage) / self.total_arbitrage_percentage
            bet_amounts.append(round(bet_amount, 2))
        
        self.bet_amounts = bet_amounts
        return bet_amounts

# %% [markdown]
# ### Parsing Events and Calculating Arbitrage Bets
# - `BET_SIZE` is the amount of money in USD that you would like to bet across the outcomes of an event.
# - This calculation will used unbiased arbitrage, where the profit is the same regardless of the outcome.

# %%
events = []
for data in odds_response:
    events.append(Event(data))
    print(data)
    print()
    
arbitrage_events = []
print(arbitrage_events)
for event in events:
    best_odds = event.find_best_odds()
    print(best_odds)
    if event.arbitrage():
        arbitrage_events.append(event)
        
for event in arbitrage_events:
    event.calculate_arbitrage_bets()
    event.convert_decimal_to_american()
# Out:
# {'id': '1527eddeab7d5bf553d0f95b53885a06', 'sport_key': 'soccer_efl_champ', 'sport_title': 'Championship', 'commence_time': '2023-04-07T11:32:16Z', 'home_team': 'Millwall', 'away_team': 'Luton Town', 'bookmakers': [{'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Luton Town', 'price': 5.75}, {'name': 'Millwall', 'price': 4.75}, {'name': 'Draw', 'price': 1.42}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.5}, {'name': 'Millwall', 'price': 5.3}, {'name': 'Draw', 'price': 1.37}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Luton Town', 'price': 5.75}, {'name': 'Millwall', 'price': 4.7}, {'name': 'Draw', 'price': 1.44}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Luton Town', 'price': 5.25}, {'name': 'Millwall', 'price': 4.4}, {'name': 'Draw', 'price': 1.47}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Luton Town', 'price': 5.3}, {'name': 'Millwall', 'price': 4.35}, {'name': 'Draw', 'price': 1.5}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Luton Town', 'price': 5.6}, {'name': 'Millwall', 'price': 4.8}, {'name': 'Draw', 'price': 1.42}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.0}, {'name': 'Millwall', 'price': 5.0}, {'name': 'Draw', 'price': 1.43}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-04-07T13:03:46Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:46Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.0}, {'name': 'Millwall', 'price': 5.0}, {'name': 'Draw', 'price': 1.4}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.25}, {'name': 'Millwall', 'price': 5.2}, {'name': 'Draw', 'price': 1.38}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.0}, {'name': 'Millwall', 'price': 5.0}, {'name': 'Draw', 'price': 1.38}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.25}, {'name': 'Millwall', 'price': 5.2}, {'name': 'Draw', 'price': 1.38}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-04-07T13:03:47Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:47Z', 'outcomes': [{'name': 'Luton Town', 'price': 6.25}, {'name': 'Millwall', 'price': 5.2}, {'name': 'Draw', 'price': 1.38}]}]}]}
#
# {'id': '9b42d1eed2654110b3a6d6abd47204cb', 'sport_key': 'soccer_efl_champ', 'sport_title': 'Championship', 'commence_time': '2023-04-07T12:04:22Z', 'home_team': 'Rotherham United', 'away_team': 'West Bromwich', 'bookmakers': [{'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Rotherham United', 'price': 4.25}, {'name': 'West Bromwich', 'price': 2.25}, {'name': 'Draw', 'price': 2.4}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Rotherham United', 'price': 4.5}, {'name': 'West Bromwich', 'price': 2.3}, {'name': 'Draw', 'price': 2.45}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Rotherham United', 'price': 4.3}, {'name': 'West Bromwich', 'price': 2.23}, {'name': 'Draw', 'price': 2.5}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Rotherham United', 'price': 4.1}, {'name': 'West Bromwich', 'price': 2.3}, {'name': 'Draw', 'price': 2.45}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Rotherham United', 'price': 4.45}, {'name': 'West Bromwich', 'price': 2.25}, {'name': 'Draw', 'price': 2.4}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Rotherham United', 'price': 4.2}, {'name': 'West Bromwich', 'price': 2.3}, {'name': 'Draw', 'price': 2.4}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Rotherham United', 'price': 4.5}, {'name': 'West Bromwich', 'price': 2.25}, {'name': 'Draw', 'price': 2.5}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Rotherham United', 'price': 4.5}, {'name': 'West Bromwich', 'price': 2.28}, {'name': 'Draw', 'price': 2.5}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Rotherham United', 'price': 4.4}, {'name': 'West Bromwich', 'price': 2.28}, {'name': 'Draw', 'price': 2.5}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Rotherham United', 'price': 4.5}, {'name': 'West Bromwich', 'price': 2.28}, {'name': 'Draw', 'price': 2.5}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-04-07T13:03:47Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:47Z', 'outcomes': [{'name': 'Rotherham United', 'price': 4.5}, {'name': 'West Bromwich', 'price': 2.28}, {'name': 'Draw', 'price': 2.5}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-04-07T13:03:46Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:46Z', 'outcomes': [{'name': 'Rotherham United', 'price': 4.33}, {'name': 'West Bromwich', 'price': 2.3}, {'name': 'Draw', 'price': 2.38}]}]}]}
#
# {'id': 'ce76bd659da896a52591ba0674cf60b8', 'sport_key': 'soccer_sweden_superettan', 'sport_title': 'Superettan - Sweden', 'commence_time': '2023-04-07T13:00:00Z', 'home_team': 'GAIS', 'away_team': 'IK Brage', 'bookmakers': [{'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-04-07T13:02:26Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:02:26Z', 'outcomes': [{'name': 'GAIS', 'price': 2.23}, {'name': 'IK Brage', 'price': 3.1}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-04-07T13:02:26Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:02:26Z', 'outcomes': [{'name': 'GAIS', 'price': 2.23}, {'name': 'IK Brage', 'price': 3.05}, {'name': 'Draw', 'price': 3.15}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-04-07T12:50:47Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T12:50:47Z', 'outcomes': [{'name': 'GAIS', 'price': 2.14}, {'name': 'IK Brage', 'price': 3.2}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-04-07T13:02:27Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:02:27Z', 'outcomes': [{'name': 'GAIS', 'price': 2.23}, {'name': 'IK Brage', 'price': 3.1}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-04-07T13:02:26Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:02:26Z', 'outcomes': [{'name': 'GAIS', 'price': 2.2}, {'name': 'IK Brage', 'price': 3.1}, {'name': 'Draw', 'price': 3.35}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-04-07T13:02:26Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:02:26Z', 'outcomes': [{'name': 'GAIS', 'price': 2.33}, {'name': 'IK Brage', 'price': 3.05}, {'name': 'Draw', 'price': 3.3}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-04-07T13:02:26Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:02:26Z', 'outcomes': [{'name': 'GAIS', 'price': 2.15}, {'name': 'IK Brage', 'price': 3.1}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-04-07T13:02:25Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:02:25Z', 'outcomes': [{'name': 'GAIS', 'price': 2.22}, {'name': 'IK Brage', 'price': 3.05}, {'name': 'Draw', 'price': 3.05}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-04-07T13:02:26Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:02:26Z', 'outcomes': [{'name': 'GAIS', 'price': 2.15}, {'name': 'IK Brage', 'price': 2.8}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2023-04-07T13:01:01Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:01:01Z', 'outcomes': [{'name': 'GAIS', 'price': 2.31}, {'name': 'IK Brage', 'price': 2.85}, {'name': 'Draw', 'price': 3.35}]}]}]}
#
# {'id': '46f249d0f6143ee1bab6021849e41edd', 'sport_key': 'soccer_england_league2', 'sport_title': 'League 2', 'commence_time': '2023-04-07T14:00:00Z', 'home_team': 'Harrogate Town', 'away_team': 'AFC Wimbledon', 'bookmakers': [{'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-04-07T13:03:38Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:38Z', 'outcomes': [{'name': 'AFC Wimbledon', 'price': 3.35}, {'name': 'Harrogate Town', 'price': 2.27}, {'name': 'Draw', 'price': 3.15}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-04-07T13:03:39Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:39Z', 'outcomes': [{'name': 'AFC Wimbledon', 'price': 3.4}, {'name': 'Harrogate Town', 'price': 2.2}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-04-07T13:03:38Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:38Z', 'outcomes': [{'name': 'AFC Wimbledon', 'price': 3.25}, {'name': 'Harrogate Town', 'price': 2.15}, {'name': 'Draw', 'price': 3.05}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-04-07T13:03:39Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:39Z', 'outcomes': [{'name': 'AFC Wimbledon', 'price': 3.05}, {'name': 'Harrogate Town', 'price': 2.15}, {'name': 'Draw', 'price': 2.9}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-04-07T13:03:39Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:39Z', 'outcomes': [{'name': 'AFC Wimbledon', 'price': 3.4}, {'name': 'Harrogate Town', 'price': 2.25}, {'name': 'Draw', 'price': 3.15}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-04-07T13:03:38Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:38Z', 'outcomes': [{'name': 'AFC Wimbledon', 'price': 3.4}, {'name': 'Harrogate Town', 'price': 2.2}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-04-07T13:03:40Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:40Z', 'outcomes': [{'name': 'AFC Wimbledon', 'price': 3.3}, {'name': 'Harrogate Town', 'price': 2.25}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2023-04-07T13:03:38Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:38Z', 'outcomes': [{'name': 'AFC Wimbledon', 'price': 3.05}, {'name': 'Harrogate Town', 'price': 2.24}, {'name': 'Draw', 'price': 3.05}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'AFC Wimbledon', 'price': 3.05}, {'name': 'Harrogate Town', 'price': 2.24}, {'name': 'Draw', 'price': 3.05}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-04-07T13:03:39Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:39Z', 'outcomes': [{'name': 'AFC Wimbledon', 'price': 3.4}, {'name': 'Harrogate Town', 'price': 2.2}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-04-07T13:03:39Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:39Z', 'outcomes': [{'name': 'AFC Wimbledon', 'price': 3.4}, {'name': 'Harrogate Town', 'price': 2.2}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-04-07T13:03:40Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:40Z', 'outcomes': [{'name': 'AFC Wimbledon', 'price': 3.4}, {'name': 'Harrogate Town', 'price': 2.2}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-04-07T13:03:41Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:41Z', 'outcomes': [{'name': 'AFC Wimbledon', 'price': 3.4}, {'name': 'Harrogate Town', 'price': 2.2}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-04-07T13:03:39Z', 'markets': [{'key': 'h2h', ...
#
# {'id': '9081128b565bb12255ca30c592956691', 'sport_key': 'soccer_england_league1', 'sport_title': 'League 1', 'commence_time': '2023-04-07T14:00:00Z', 'home_team': 'Accrington Stanley', 'away_team': 'Port Vale', 'bookmakers': [{'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-04-07T13:03:22Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:22Z', 'outcomes': [{'name': 'Accrington Stanley', 'price': 3.2}, {'name': 'Port Vale', 'price': 2.22}, {'name': 'Draw', 'price': 3.05}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-04-07T13:03:22Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:22Z', 'outcomes': [{'name': 'Accrington Stanley', 'price': 3.3}, {'name': 'Port Vale', 'price': 2.25}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Accrington Stanley', 'price': 3.2}, {'name': 'Port Vale', 'price': 2.28}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Accrington Stanley', 'price': 3.05}, {'name': 'Port Vale', 'price': 2.15}, {'name': 'Draw', 'price': 2.9}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-04-07T13:03:22Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:22Z', 'outcomes': [{'name': 'Accrington Stanley', 'price': 3.3}, {'name': 'Port Vale', 'price': 2.25}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Accrington Stanley', 'price': 3.2}, {'name': 'Port Vale', 'price': 2.2}, {'name': 'Draw', 'price': 3.3}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-04-07T13:01:30Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:01:30Z', 'outcomes': [{'name': 'Accrington Stanley', 'price': 3.3}, {'name': 'Port Vale', 'price': 2.2}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Accrington Stanley', 'price': 3.25}, {'name': 'Port Vale', 'price': 2.23}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-04-07T13:03:24Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:24Z', 'outcomes': [{'name': 'Accrington Stanley', 'price': 3.25}, {'name': 'Port Vale', 'price': 2.23}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Accrington Stanley', 'price': 3.25}, {'name': 'Port Vale', 'price': 2.23}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Accrington Stanley', 'price': 3.25}, {'name': 'Port Vale', 'price': 2.23}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Accrington Stanley', 'price': 3.25}, {'name': 'Port Vale', 'price': 2.23}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Accrington Stanley', 'price': 3.0}, {'name': 'Port Vale', 'price': 2.25}, {'name': 'Draw', 'price': 3.1}]}]}]}
#
# {'id': 'd83a11917b940a6a7ad4d33d9a466772', 'sport_key': 'soccer_england_league1', 'sport_title': 'League 1', 'commence_time': '2023-04-07T14:00:00Z', 'home_team': 'Burton Albion', 'away_team': 'Barnsley', 'bookmakers': [{'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-04-07T13:03:22Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:22Z', 'outcomes': [{'name': 'Barnsley', 'price': 1.82}, {'name': 'Burton Albion', 'price': 4.05}, {'name': 'Draw', 'price': 3.4}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-04-07T13:03:22Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:22Z', 'outcomes': [{'name': 'Barnsley', 'price': 1.8}, {'name': 'Burton Albion', 'price': 4.2}, {'name': 'Draw', 'price': 3.6}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Barnsley', 'price': 1.85}, {'name': 'Burton Albion', 'price': 4.0}, {'name': 'Draw', 'price': 3.7}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Barnsley', 'price': 1.75}, {'name': 'Burton Albion', 'price': 3.8}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-04-07T13:03:22Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:22Z', 'outcomes': [{'name': 'Barnsley', 'price': 1.83}, {'name': 'Burton Albion', 'price': 4.3}, {'name': 'Draw', 'price': 3.7}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Barnsley', 'price': 1.82}, {'name': 'Burton Albion', 'price': 4.2}, {'name': 'Draw', 'price': 3.65}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-04-07T13:01:30Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:01:30Z', 'outcomes': [{'name': 'Barnsley', 'price': 1.83}, {'name': 'Burton Albion', 'price': 4.1}, {'name': 'Draw', 'price': 3.6}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Barnsley', 'price': 1.83}, {'name': 'Burton Albion', 'price': 4.1}, {'name': 'Draw', 'price': 3.6}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-04-07T13:03:24Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:24Z', 'outcomes': [{'name': 'Barnsley', 'price': 1.83}, {'name': 'Burton Albion', 'price': 4.1}, {'name': 'Draw', 'price': 3.6}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Barnsley', 'price': 1.83}, {'name': 'Burton Albion', 'price': 4.1}, {'name': 'Draw', 'price': 3.6}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Barnsley', 'price': 1.83}, {'name': 'Burton Albion', 'price': 4.1}, {'name': 'Draw', 'price': 3.6}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Barnsley', 'price': 1.83}, {'name': 'Burton Albion', 'price': 4.1}, {'name': 'Draw', 'price': 3.6}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Barnsley', 'price': 1.82}, {'name': 'Burton Albion', 'price': 3.7}, {'name': 'Draw', 'price': 3.5}]}]}]}
#
# {'id': '8a44e273636674bedc81b4a7ddc012f1', 'sport_key': 'soccer_england_league2', 'sport_title': 'League 2', 'commence_time': '2023-04-07T14:00:00Z', 'home_team': 'Crewe Alexandra', 'away_team': 'Barrow', 'bookmakers': [{'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-04-07T13:03:38Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:38Z', 'outcomes': [{'name': 'Barrow', 'price': 2.2}, {'name': 'Crewe Alexandra', 'price': 3.25}, {'name': 'Draw', 'price': 2.95}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-04-07T13:03:39Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:39Z', 'outcomes': [{'name': 'Barrow', 'price': 2.25}, {'name': 'Crewe Alexandra', 'price': 3.4}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-04-07T13:03:38Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:38Z', 'outcomes': [{'name': 'Barrow', 'price': 2.27}, {'name': 'Crewe Alexandra', 'price': 3.4}, {'name': 'Draw', 'price': 3.05}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-04-07T13:03:39Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:39Z', 'outcomes': [{'name': 'Barrow', 'price': 2.15}, {'name': 'Crewe Alexandra', 'price': 3.15}, {'name': 'Draw', 'price': 2.8}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-04-07T13:03:39Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:39Z', 'outcomes': [{'name': 'Barrow', 'price': 2.3}, {'name': 'Crewe Alexandra', 'price': 3.45}, {'name': 'Draw', 'price': 3.05}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-04-07T13:03:38Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:38Z', 'outcomes': [{'name': 'Barrow', 'price': 2.24}, {'name': 'Crewe Alexandra', 'price': 3.4}, {'name': 'Draw', 'price': 3.12}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-04-07T13:03:40Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:40Z', 'outcomes': [{'name': 'Barrow', 'price': 2.25}, {'name': 'Crewe Alexandra', 'price': 3.3}, {'name': 'Draw', 'price': 3.0}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2023-04-07T13:03:38Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:38Z', 'outcomes': [{'name': 'Barrow', 'price': 2.21}, {'name': 'Crewe Alexandra', 'price': 3.3}, {'name': 'Draw', 'price': 2.89}]}]}, {'key': 'lowvig', 'title': 'LowVig.ag', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Barrow', 'price': 2.21}, {'name': 'Crewe Alexandra', 'price': 3.3}, {'name': 'Draw', 'price': 2.89}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-04-07T13:03:39Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:39Z', 'outcomes': [{'name': 'Barrow', 'price': 2.2}, {'name': 'Crewe Alexandra', 'price': 3.4}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-04-07T13:03:39Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:39Z', 'outcomes': [{'name': 'Barrow', 'price': 2.2}, {'name': 'Crewe Alexandra', 'price': 3.4}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-04-07T13:03:40Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:40Z', 'outcomes': [{'name': 'Barrow', 'price': 2.2}, {'name': 'Crewe Alexandra', 'price': 3.4}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-04-07T13:03:41Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:41Z', 'outcomes': [{'name': 'Barrow', 'price': 2.2}, {'name': 'Crewe Alexandra', 'price': 3.4}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-04-07T13:03:39Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:39Z', 'outcomes': [{'name': 'Barrow', 'price': 2.2} ...
#
# {'id': '44995a5ff946a48dbacac067f0e9a7f9', 'sport_key': 'soccer_efl_champ', 'sport_title': 'Championship', 'commence_time': '2023-04-07T14:00:00Z', 'home_team': 'Reading', 'away_team': 'Birmingham City', 'bookmakers': [{'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Birmingham City', 'price': 2.5}, {'name': 'Reading', 'price': 3.1}, {'name': 'Draw', 'price': 2.95}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Birmingham City', 'price': 2.45}, {'name': 'Reading', 'price': 3.1}, {'name': 'Draw', 'price': 3.0}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Birmingham City', 'price': 2.45}, {'name': 'Reading', 'price': 3.05}, {'name': 'Draw', 'price': 2.95}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Birmingham City', 'price': 2.45}, {'name': 'Reading', 'price': 3.1}, {'name': 'Draw', 'price': 2.95}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Birmingham City', 'price': 2.57}, {'name': 'Reading', 'price': 3.04}, {'name': 'Draw', 'price': 3.02}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Birmingham City', 'price': 2.6}, {'name': 'Reading', 'price': 3.1}, {'name': 'Draw', 'price': 3.0}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Birmingham City', 'price': 2.55}, {'name': 'Reading', 'price': 3.05}, {'name': 'Draw', 'price': 2.85}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2023-04-07T13:03:46Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:46Z', 'outcomes': [{'name': 'Birmingham City', 'price': 2.55}, {'name': 'Reading', 'price': 3.05}, {'name': 'Draw', 'price': 3.0}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Birmingham City', 'price': 2.5}, {'name': 'Reading', 'price': 3.1}, {'name': 'Draw', 'price': 2.9}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Birmingham City', 'price': 2.5}, {'name': 'Reading', 'price': 3.1}, {'name': 'Draw', 'price': 2.9}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Birmingham City', 'price': 2.5}, {'name': 'Reading', 'price': 3.1}, {'name': 'Draw', 'price': 2.9}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Birmingham City', 'price': 2.5}, {'name': 'Reading', 'price': 3.1}, {'name': 'Draw', 'price': 2.9}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-04-07T13:03:47Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:47Z', 'outcomes': [{'name': 'Birmingham City', 'price': 2.5}, {'name': 'Reading', 'price': 3.1}, {'name': 'Draw', 'price': 2.9}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Birmingh ...
#
# {'id': '9a618f2fd81a465c2f78d5b5a635bcad', 'sport_key': 'soccer_efl_champ', 'sport_title': 'Championship', 'commence_time': '2023-04-07T14:00:00Z', 'home_team': 'Blackburn Rovers', 'away_team': 'Norwich City', 'bookmakers': [{'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackburn Rovers', 'price': 2.65}, {'name': 'Norwich City', 'price': 2.7}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackburn Rovers', 'price': 2.65}, {'name': 'Norwich City', 'price': 2.7}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackburn Rovers', 'price': 2.55}, {'name': 'Norwich City', 'price': 2.75}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Blackburn Rovers', 'price': 2.65}, {'name': 'Norwich City', 'price': 2.65}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackburn Rovers', 'price': 2.64}, {'name': 'Norwich City', 'price': 2.76}, {'name': 'Draw', 'price': 3.24}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackburn Rovers', 'price': 2.75}, {'name': 'Norwich City', 'price': 2.6}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackburn Rovers', 'price': 2.65}, {'name': 'Norwich City', 'price': 2.8}, {'name': 'Draw', 'price': 3.3}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2023-04-07T13:03:46Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:46Z', 'outcomes': [{'name': 'Blackburn Rovers', 'price': 2.65}, {'name': 'Norwich City', 'price': 2.75}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackburn Rovers', 'price': 2.65}, {'name': 'Norwich City', 'price': 2.65}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Blackburn Rovers', 'price': 2.65}, {'name': 'Norwich City', 'price': 2.65}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Blackburn Rovers', 'price': 2.65}, {'name': 'Norwich City', 'price': 2.65}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Blackburn Rovers', 'price': 2.65}, {'name': 'Norwich City', 'price': 2.65}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-04-07T13:03:47Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:47Z', 'outcomes': [{'name': 'Blackburn Rovers', 'price': 2.65}, {'name': 'Norwich City', 'price': 2.65}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2023-04-07T13:03:45Z', 'mar ...
#
# {'id': '61b99bd25c509444e4472bd02cff040f', 'sport_key': 'soccer_efl_champ', 'sport_title': 'Championship', 'commence_time': '2023-04-07T14:00:00Z', 'home_team': 'Blackpool', 'away_team': 'Cardiff City', 'bookmakers': [{'key': 'pointsbetus', 'title': 'PointsBet (US)', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackpool', 'price': 2.5}, {'name': 'Cardiff City', 'price': 2.9}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackpool', 'price': 2.5}, {'name': 'Cardiff City', 'price': 2.9}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackpool', 'price': 2.5}, {'name': 'Cardiff City', 'price': 2.85}, {'name': 'Draw', 'price': 3.05}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Blackpool', 'price': 2.5}, {'name': 'Cardiff City', 'price': 2.88}, {'name': 'Draw', 'price': 3.15}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackpool', 'price': 2.55}, {'name': 'Cardiff City', 'price': 2.9}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackpool', 'price': 2.55}, {'name': 'Cardiff City', 'price': 2.95}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackpool', 'price': 2.55}, {'name': 'Cardiff City', 'price': 2.85}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'superbook', 'title': 'SuperBook', 'last_update': '2023-04-07T13:03:46Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:46Z', 'outcomes': [{'name': 'Blackpool', 'price': 2.55}, {'name': 'Cardiff City', 'price': 2.9}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-04-07T13:03:44Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:44Z', 'outcomes': [{'name': 'Blackpool', 'price': 2.55}, {'name': 'Cardiff City', 'price': 2.88}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Blackpool', 'price': 2.55}, {'name': 'Cardiff City', 'price': 2.88}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Blackpool', 'price': 2.55}, {'name': 'Cardiff City', 'price': 2.88}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Blackpool', 'price': 2.55}, {'name': 'Cardiff City', 'price': 2.88}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-04-07T13:03:47Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:47Z', 'outcomes': [{'name': 'Blackpool', 'price': 2.55}, {'name': 'Cardiff City', 'price': 2.88}, {'name': 'Draw', 'price': 3.1}]}]}, {'key': 'betus', 'title': 'BetUS', 'last_update': '2023-04-07T13:03:45Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:45Z', 'outcomes': [{'name': 'Blackpool', 'pric ...
#
# {'id': 'f2336234191de532d03e8507c1b63fa2', 'sport_key': 'soccer_england_league1', 'sport_title': 'League 1', 'commence_time': '2023-04-07T14:00:00Z', 'home_team': 'Exeter City', 'away_team': 'Bolton', 'bookmakers': [{'key': 'williamhill_us', 'title': 'William Hill (US)', 'last_update': '2023-04-07T13:03:22Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:22Z', 'outcomes': [{'name': 'Bolton', 'price': 2.5}, {'name': 'Exeter City', 'price': 2.75}, {'name': 'Draw', 'price': 3.05}]}]}, {'key': 'fanduel', 'title': 'FanDuel', 'last_update': '2023-04-07T13:03:22Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:22Z', 'outcomes': [{'name': 'Bolton', 'price': 2.55}, {'name': 'Exeter City', 'price': 2.8}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'mybookieag', 'title': 'MyBookie.ag', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Bolton', 'price': 2.55}, {'name': 'Exeter City', 'price': 2.8}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'foxbet', 'title': 'FOX Bet', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Bolton', 'price': 2.35}, {'name': 'Exeter City', 'price': 2.65}, {'name': 'Draw', 'price': 2.95}]}]}, {'key': 'draftkings', 'title': 'DraftKings', 'last_update': '2023-04-07T13:03:22Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:22Z', 'outcomes': [{'name': 'Bolton', 'price': 2.55}, {'name': 'Exeter City', 'price': 2.8}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'bovada', 'title': 'Bovada', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Bolton', 'price': 2.5}, {'name': 'Exeter City', 'price': 2.75}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'betmgm', 'title': 'BetMGM', 'last_update': '2023-04-07T13:01:30Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:01:30Z', 'outcomes': [{'name': 'Bolton', 'price': 2.45}, {'name': 'Exeter City', 'price': 2.8}, {'name': 'Draw', 'price': 3.2}]}]}, {'key': 'twinspires', 'title': 'TwinSpires', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Bolton', 'price': 2.55}, {'name': 'Exeter City', 'price': 2.75}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'unibet_us', 'title': 'Unibet', 'last_update': '2023-04-07T13:03:24Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:24Z', 'outcomes': [{'name': 'Bolton', 'price': 2.55}, {'name': 'Exeter City', 'price': 2.75}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'betrivers', 'title': 'BetRivers', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Bolton', 'price': 2.55}, {'name': 'Exeter City', 'price': 2.75}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'sugarhouse', 'title': 'SugarHouse', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Bolton', 'price': 2.55}, {'name': 'Exeter City', 'price': 2.75}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'barstool', 'title': 'Barstool Sportsbook', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Bolton', 'price': 2.55}, {'name': 'Exeter City', 'price': 2.75}, {'name': 'Draw', 'price': 3.25}]}]}, {'key': 'betonlineag', 'title': 'BetOnline.ag', 'last_update': '2023-04-07T13:03:23Z', 'markets': [{'key': 'h2h', 'last_update': '2023-04-07T13:03:23Z', 'outcomes': [{'name': 'Bolton', 'price': 2.43}, {'name': 'Exeter City', 'price': 2.74}, {'name': 'Draw', 'price': 3.1}]}]}]}
#
# []
# [['FanDuel', 'Luton Town', 6.5], ['FanDuel', 'Millwall', 5.3], ['MyBookie.ag', 'Draw', 1.5]]
# [['FanDuel', 'Rotherham United', 4.5], ['FanDuel', 'West Bromwich', 2.3], ['William Hill (US)', 'Draw', 2.5]]
# [['MyBookie.ag', 'GAIS', 2.33], ['BetRivers', 'IK Brage', 3.2], ['Bovada', 'Draw', 3.35]]
# [['FanDuel', 'AFC Wimbledon', 3.4], ['MyBookie.ag', 'Harrogate Town', 2.27], ['Bovada', 'Draw', 3.2]]
# [['FanDuel', 'Accrington Stanley', 3.3], ['MyBookie.ag', 'Port Vale', 2.28], ['Bovada', 'Draw', 3.3]]
# [['MyBookie.ag', 'Barnsley', 1.85], ['DraftKings', 'Burton Albion', 4.3], ['MyBookie.ag', 'Draw', 3.7]]
# [['DraftKings', 'Barrow', 2.3], ['DraftKings', 'Crewe Alexandra', 3.45], ['Bovada', 'Draw', 3.12]]
# [['DraftKings', 'Birmingham City', 2.6], ['PointsBet (US)', 'Reading', 3.1], ['MyBookie.ag', 'Draw', 3.02]]
# [['BetUS', 'Blackburn Rovers', 2.8], ['DraftKings', 'Norwich City', 2.8], ['DraftKings', 'Draw', 3.3]]
# [['BetUS', 'Blackpool', 2.7], ['DraftKings', 'Cardiff City', 2.95], ['MyBookie.ag', 'Draw', 3.2]]
# [['FanDuel', 'Bolton', 2.55], ['FanDuel', 'Exeter City', 2.8], ['DraftKings', 'Draw', 3.25]]

# %% [markdown]
# ### Creating Dataframe and Writing to Excel File

# %%
MAX_OUTCOMES = max([event.num_outcomes for event in arbitrage_events])
ARBITRAGE_EVENTS_COUNT = len(arbitrage_events)

my_columns = ['ID', 'Sport Key', 'Expected Earnings'] + list(np.array([[f'Bookmaker #{outcome}', f'Name #{outcome}', f'Odds #{outcome}', f'Amount to Buy #{outcome}'] for outcome in range(1, MAX_OUTCOMES + 1)]).flatten())
dataframe = pd.DataFrame(columns=my_columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 MAX_OUTCOMES = max([event.num_outcomes for event in arbitrage_events])
#       2 ARBITRAGE_EVENTS_COUNT = len(arbitrage_events)
#       4 my_columns = ['ID', 'Sport Key', 'Expected Earnings'] + list(np.array([[f'Bookmaker #{outcome}', f'Name #{outcome}', f'Odds #{outcome}', f'Amount to Buy #{outcome}'] for outcome in range(1, MAX_OUTCOMES + 1)]).flatten())
#
# ValueError: max() arg is an empty sequence

# %%
for event in arbitrage_events:
    # print(event.best_odds)
    row = []
    row.append(event.id)
    row.append(event.sport_key)
    row.append(round(event.expected_earnings, 2))
    for index, outcome in enumerate(event.best_odds):
        row.append(outcome[BOOKMAKER_INDEX])
        row.append(outcome[NAME_INDEX])
        row.append(outcome[ODDS_INDEX])
        row.append(event.bet_amounts[index])
    while len(row) < len(dataframe.columns):
        row.append('N/A')
    dataframe.loc[len(dataframe.index)] = row

# %%
writer = pd.ExcelWriter('bets.xlsx')
dataframe.to_excel(writer, index=False)
writer.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 writer = pd.ExcelWriter('bets.xlsx')
# ----> 2 dataframe.to_excel(writer, index=False)
#       3 writer.save()
#
# NameError: name 'dataframe' is not defined

# %% [markdown]
# ### Formatting the Excel File

# %%
BLACK = '000000'
LIGHT_GREY = 'D6D6D6'
DARK_GREY = '9F9F9F'
RED = 'FEA0A0'
BLUE = 'A0CEFE'
YELLOW = 'FFE540'

COLORS = [RED, BLUE]

ID_COLUMN_FILL = PatternFill(fill_type='solid', start_color=DARK_GREY, end_color=DARK_GREY)
SPORT_KEY_COLUMN_FILL = PatternFill(fill_type='solid', start_color=LIGHT_GREY, end_color=LIGHT_GREY)
EXPECTED_EARNINGS_COLUMN_FILL = PatternFill(fill_type='solid', start_color=YELLOW, end_color=YELLOW)

CENTER_ALIGNMENT = Alignment(horizontal='center', vertical='bottom', indent=0)

TOP_ROW_BORDER = Border(bottom=Side(border_style='thick', color=BLACK))
NORMAL_ROW_BORDER = Border(top=Side(border_style='thin', color=LIGHT_GREY), bottom=Side(border_style='thin', color=DARK_GREY))

wb = load_workbook('bets.xlsx')
ws = wb.active
ws.title = 'Upcoming'
# changing width
for col in range(1, 26):
    ws.column_dimensions[chr(col + 64)].width = 20

for cell in ws['A']:
    cell.fill = ID_COLUMN_FILL
    cell.alignment = CENTER_ALIGNMENT
    
for cell in ws['B']:
    cell.fill = SPORT_KEY_COLUMN_FILL
    cell.alignment = CENTER_ALIGNMENT
    
for cell in ws['C']:
    cell.fill = EXPECTED_EARNINGS_COLUMN_FILL
    cell.alignment = CENTER_ALIGNMENT
    cell.number_format = numbers.BUILTIN_FORMATS[7]

START_INDEX = 'D'
for index in range(MAX_OUTCOMES):
    for col in ws[START_INDEX : chr(ord(START_INDEX) + 3)]:
        for cell in col:
            color = COLORS[int(index % 2)]
            cell.fill = PatternFill(fill_type='solid', start_color=color, end_color=color)
            cell.alignment = CENTER_ALIGNMENT
            if cell.column % 4 == 3:
                cell.number_format = numbers.BUILTIN_FORMATS[7]
            
    START_INDEX = chr(ord(START_INDEX) + 4)

for cell in ws['1']:
    cell.border = TOP_ROW_BORDER

for row in range(2, ARBITRAGE_EVENTS_COUNT + 2):
    for cell in ws[str(row)]:
        cell.border = NORMAL_ROW_BORDER
    
wb.save('upcoming_events_bets.xlsx')
